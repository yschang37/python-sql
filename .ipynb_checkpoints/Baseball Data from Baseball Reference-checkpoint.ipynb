# %% [markdown]
# # This python file is to show how to use beaufisoup library to scrape the data      from
# https://www.baseball-reference.com/players/t/troutmi01.shtml

# %% [markdown]
# I write the code to get the Mike Trout's Standard Batting.
# ![Capture.PNG](attachment:Capture.PNG)

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import pandas as pd
import numpy as np

# this function is to output the dataframe
def StandardBatting():
    data = []
    #get the url
    url = 'https://www.baseball-reference.com/players/t/troutmi01.shtml'
    #use requests to get the data from url
    res = requests.get(url)
    #use html.paser to know the detail
    soup = BeautifulSoup(res.text, 'html.parser')
    #this col is to rename the columns
    col = []
    
    #get the detail about the columns
    for sta in soup.find_all('table', attrs={'class':'row_summable sortable stats_table'}):

        for sta_detail in sta.find_all('thead'):

            for sta_detail_2 in sta_detail.find_all('tr'):
                for sta_detail_3 in sta_detail.find_all('th'):
                    col.append(sta_detail_3.text)

    # get the data from table
    cc = pd.DataFrame([])
    df = pd.DataFrame([])
    for sta in soup.find_all('table', attrs={'class':'row_summable sortable stats_table'}):
        for sta_detail in sta.find_all('tbody'):
            for sta_detail_2 in sta_detail.find_all('tr'):
                data = []
                data.append(sta_detail_2.find('th').text)
                for sta_detail_3 in sta_detail_2.find_all('td'):
                    data.append(sta_detail_3.text)
                    if len(data) >= 30:
                        df = df.append([data],ignore_index=True)
    df.rename(index=str, columns={int(i):col[i] for i in range(30)})
    df.columns = col
    print(df)
    return df

# %%
df = StandardBatting()
# Out:
#     Year Age       Tm    Lg    G   PA   AB    R    H  2B         ...           \
# 0   2009  17  LAA-min  Rk,A   44  207  179   30   63   7         ...
# 1   2010  18  LAA-min  A,A+  131  600  508  106  173  28         ...
# 2   2011  19  LAA-min    AA   91  412  353   82  115  18         ...
# 3   2011  19      LAA    AL   40  135  123   20   27   6         ...
# 4   2012  20  LAA-min   AAA   20   93   77   21   31   4         ...
# 5   2012  20      LAA    AL  139  639  559  129  182  27         ...
# 6   2013  21      LAA    AL  157  716  589  109  190  39         ...
# 7   2014  22      LAA    AL  157  705  602  115  173  39         ...
# 8   2015  23      LAA    AL  159  682  575  104  172  32         ...
# 9   2016  24      LAA    AL  159  681  549  123  173  32         ...
# 10  2017  25  LAA-min    A+    4   14    9    5    2   1         ...
# 11  2017  25      LAA    AL  114  507  402   92  123  25         ...
# ...

# %%
df
# Out:
#     Year Age       Tm    Lg    G   PA   AB    R    H  2B         ...           \
# 0   2009  17  LAA-min  Rk,A   44  207  179   30   63   7         ...
# 1   2010  18  LAA-min  A,A+  131  600  508  106  173  28         ...
# 2   2011  19  LAA-min    AA   91  412  353   82  115  18         ...
# 3   2011  19      LAA    AL   40  135  123   20   27   6         ...
# 4   2012  20  LAA-min   AAA   20   93   77   21   31   4         ...
# 5   2012  20      LAA    AL  139  639  559  129  182  27         ...
# 6   2013  21      LAA    AL  157  716  589  109  190  39         ...
# 7   2014  22      LAA    AL  157  705  602  115  173  39         ...
# 8   2015  23      LAA    AL  159  682  575  104  172  32         ...
# 9   2016  24      LAA    AL  159  681  549  123  173  32         ...
# 10  2017  25  LAA-min    A+    4   14    9    5    2   1         ...
# 11  2017  25      LAA    AL  114  507  402   92  123  25         ...
# ...

# %%
# to get the year and games data
def year_game():
    years = np.array(df.loc[:,'Year'])
    games = np.array(df.loc[:,'G'])
    combine = {}
    key = []
    for i in range(len(games)):

        if years[i] in key:
            combine[years[i]] = int(combine[years[i]])+int(games[i])
            key, value = years[i], games[i]
        else:
            combine[years[i]] = int(games[i])
            key, value = years[i], games[i]
    return combine

# %%
import matplotlib.pyplot as plt
combine = year_game()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()

# %%
def year_r():
    years = np.array(df.loc[:,'Year'])
    run = np.array(df.loc[:,'R'])
    combine = {}
    key = []
    for i in range(len(games)):

        if years[i] in key:
            combine[years[i]] = int(combine[years[i]])+int(run[i])
            key, value = years[i], run[i]
        else:
            combine[years[i]] = int(run[i])
            key, value = years[i], run[i]
    return combine

# %%
combine = year_r()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()

# %%
combine = year_r()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()

# %%
def year_h():
    years = np.array(df.loc[:,'Year'])
    hit = np.array(df.loc[:,'H'])
    combine = {}
    key = []
    for i in range(len(hit)):

        if years[i] in key:
            combine[years[i]] = int(combine[years[i]])+int(hit[i])
            key, value = years[i], hit[i]
        else:
            combine[years[i]] = int(hit[i])
            key, value = years[i], hit[i]
    return combine

# %%
combine = year_h()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()

# %%
def year_2b():
    years = np.array(df.loc[:,'Year'])
    double = np.array(df.loc[:,'3B'])
    combine = {}
    key = []
    for i in range(len(double)):

        if years[i] in key:
            combine[years[i]] = int(combine[years[i]])+int(double[i])
            key, value = years[i], double[i]
        else:
            combine[years[i]] = int(double[i])
            key, value = years[i], double[i]
    return combine

# %%
combine = year_2b()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()

# %%
def year_3b():
    years = np.array(df.loc[:,'Year'])
    Third = np.array(df.loc[:,'3B'])
    combine = {}
    key = []
    for i in range(len(Third)):

        if years[i] in key:
            combine[years[i]] = int(combine[years[i]])+int(Third[i])
            key, value = years[i], Third[i]
        else:
            combine[years[i]] = int(Third[i])
            key, value = years[i], Third[i]
    return combine

# %%
combine = year_3b()
x_axis = [i for i in combine]
y_axis = [combine[i] for i in combine]
plt.plot(x_axis,y_axis)
plt.ylabel('Number of games(include the minor league)')
plt.show()
